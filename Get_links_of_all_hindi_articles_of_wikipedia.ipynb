# %%
from urllib.request import urlopen
import pickle

# %%
html_doc = ''
with urlopen('https://hi.wikipedia.org/wiki/%E0%A4%AE%E0%A5%81%E0%A4%96%E0%A4%AA%E0%A5%83%E0%A4%B7%E0%A5%8D%E0%A4%A0') as response:
    for line in response:
        line = line.decode('utf-8')
        html_doc = html_doc + line.replace('\n','')

# %%
from bs4 import BeautifulSoup
import lxml
soup = BeautifulSoup(html_doc, 'lxml')

# %%
soup.h1.string
# Out:
# 'मुखपृष्ठ'

# %%
tab = soup.find("table",{"style":"border:2px solid #e1eaee; border-collapse:separate;font-size:120%"})

# %%
anchors = tab.find_all('a')

# %%
home_url = 'https://hi.wikipedia.org' 
links = [home_url + anchor['href'] for anchor in anchors]

# %%
len(links)
# Out:
# 54

# %%
all_links = []

# %%
prev_len = 0
for link in links:    
    while link:
        html_doc = ''
        with urlopen(link) as response:
            for line in response:
                line = line.decode('utf-8')
                html_doc = html_doc + line.replace('\n','')
            soup = BeautifulSoup(html_doc, 'lxml')
            div = soup.find('div',{'class':'mw-allpages-body'})
            if div:
                anchors = div.find_all('a');
                all_links = all_links + [home_url + anchor['href'] for anchor in anchors]
            if prev_len == len(set(all_links)):
                break
            nav_div = soup.find('div',{'class':'mw-allpages-nav'})
            if nav_div and len(nav_div.find_all('a')) == 2:
                link = home_url + nav_div.find_all('a')[1]['href']
            prev_len = len(set(all_links))
# Out:
# 345
# 690
# 1035
# 1380
# 1725
# 2070
# 2415
# 2760
# 2848
# 2848
# 3193
# 3538
# 3883
# 4228
# 4573
# 4918
# 5263
# 5608
# 5953
# 6298
# 6643
# 6988
# 7333
# 7678
# 8023
# 8368
# 8713
# 9058
# 9403
# 9748
# 10093
# 10438
# 10783
# 11128
# 11473
# 11818
# 12163
# 12508
# 12853
# 13198
# 13543
# 13888
# 14233
# 14578
# 14923
# 15268
# 15613
# 15958
# 16303
# 16648
# 16993
# 17338
# 17683
# 18028
# 18373
# 18718
# 19063
# 19408
# 19753
# 20098
# 20443
# 20788
# 21133
# 21478
# 21823
# 22168
# 22513
# 22858
# 23203
# 23548
# 23893
# 24238
# 24583
# 24928
# 25273
# 25618
# 25963
# 26308
# 26653
# 26998
# 27343
# 27688
# 28033
# 28378
# 28723
# 29068
# 29413
# 29758
# 30103
# 30448
# 30793
# 31138
# 31483
# 31828
# 32173
# 32518
# 32863
# 33208
# 33553
# 33898
# 34243
# 34588
# 34933
# 35278
# 35623
# 35968
# 36313
# 36658
# 37003
# 37348
# 37693
# 38038
# 38383
# 38728
# 39073
# 39418
# 39763
# 40108
# 40453
# 40798
# 41143
# 41488
# 41833
# 42178
# 42523
# 42868
# 43213
# 43558
# 43903
# 44248
# 44593
# 44938
# 45283
# 45628
# 45973
# 46318
# 46663
# 47008
# 47353
# 47698
# 48043
# 48388
# 48733
# 49078
# 49423
# 49768
# 50113
# 50458
# 50803
# 51148
# 51493
# 51838
# 52183
# 52528
# 52873
# 53218
# 53563
# 53908
# 54253
# 54598
# 54943
# 55288
# 55633
# 55978
# 56323
# 56668
# 57013
# 57358
# 57703
# 58048
# 58393
# 58738
# 59083
# 59428
# 59773
# 60118
# 60463
# 60808
# 61153
# 61498
# 61843
# 62188
# 62533
# 62878
# 63223
# 63568
# 63913
# 64258
# 64603
# 64948
# 65293
# 65638
# 65983
# 66328
# 66673
# 67018
# 67363
# 67708
# 68053
# 68398
# 68743
# 69088
# 69433
# 69778
# 70123
# 70468
# 70813
# 71158
# 71503
# 71848
# 72193
# 72538
# 72883
# 73228
# 73573
# 73918
# 74263
# 74608
# 74953
# 75298
# 75643
# 75988
# 76333
# 76678
# 77023
# 77368
# 77713
# 78058
# 78403
# 78748
# 79093
# 79438
# 79783
# 80128
# 80473
# 80818
# 81163
# 81508
# 81853
# 82198
# 82543
# 82888
# 83233
# 83578
# 83923
# 84268
# 84613
# 84958
# 85303
# 85648
# 85993
# 86338
# 86683
# 87028
# 87373
# 87718
# 88063
# 88408
# 88753
# 89098
# 89443
# 89788
# 90133
# 90478
# 90823
# 91168
# 91513
# 91858
# 92203
# 92548
# 92893
# 93238
# 93583
# 93928
# 94273
# 94618
# 94963
# 95308
# 95653
# 95998
# 96343
# 96688
# 97033
# 97378
# 97723
# 98068
# 98413
# 98758
# 99103
# 99448
# 99793
# 100138
# 100483
# 100828
# 101173
# 101518
# 101863
# 102208
# 102553
# 102898
# 103243
# 103588
# 103933
# 104278
# 104623
# 104968
# 105313
# 105658
# 106003
# 106348
# 106693
# 107038
# 107383
# 107728
# 108073
# 108418
# 108763
# 109108
# 109453
# 109798
# 110143
# 110488
# 110833
# 111178
# 111523
# 111868
# 112213
# 112558
# 112903
# 113248
# 113593
# 113938
# 114283
# 114628
# 114973
# 115318
# 115663
# 116008
# 116353
# 116698
# 117043
# 117388
# 117733
# 118078
# 118423
# 118768
# 119113
# 119458
# 119803
# 120148
# 120493
# 120838
# 121183
# 121528
# 121873
# 122218
# 122563
# 122908
# 123253
# 123598
# 123943
# 124288
# 124633
# 124978
# 125323
# 125668
# 126013
# 126358
# 126703
# 127048
# 127393
# 127738
# 128083
# 128428
# 128773
# 129118
# 129463
# 129808
# 130153
# 130498
# 130843
# 131188
# 131533
# 131878
# 132223
# 132568
# 132913
# 133258
# 133603
# 133948
# 134293
# 134638
# 134983
# 135328
# 135673
# 136018
# 136363
# 136708
# 137053
# 137398
# 137743
# 138088
# 138433
# 138778
# 139123
# 139468
# 139813
# 140158
# 140503
# 140848
# 141193
# 141538
# 141883
# 142228
# 142573
# 142918
# 143263
# 143608
# 143953
# 144298
# 144643
# 144988
# 145333
# 145678
# 146023
# 146368
# 146713
# 147058
# 147403
# 147748
# 148093
# 148438
# 148783
# 149128
# 149473
# 149818
# 150163
# 150508
# 150853
# 151198
# 151543
# 151888
# 152233
# 152578
# 152923
# 153268
# 153613
# 153958
# 154303
# 154648
# 154993
# 155338
# 155683
# 156028
# 156373
# 156718
# 157063
# 157408
# 157753
# 158098
# 158443
# 158788
# 159133
# 159478
# 159823
# 160168
# 160513
# 160858
# 161203
# 161548
# 161893
# 162238
# 162583
# 162928
# 163273
# 163618
# 163963
# 164308
# 164653
# 164998
# 165343
# 165688
# 166033
# 166378
# 166723
# 167068
# 167413
# 167758
# 168103
# 168448
# 168793
# 169138
# 169483
# 169828
# 170173
# 170518
# 170863
# 171208
# 171553
# 171898
# 172243
# 172588
# 172933
# 173278
# 173623
# 173968
# 174313
# 174658
# 175003
# 175348
# 175693
# 176038
# 176383
# 176728
# 177073
# 177418
# 177763
# 178108
# 178453
# 178798
# 179143
# 179488
# 179833
# 180178
# 180523
# 180868
# 181213
# 181558
# 181903
# 182248
# 182593
# 182938
# 183283
# 183628
# 183973
# 184318
# 184663
# 185008
# 185353
# 185698
# 186043
# 186388
# 186733
# 187078
# 187423
# 187768
# 188113
# 188458
# 188803
# 189148
# 189493
# 189838
# 190183
# 190528
# 190873
# 191218
# 191563
# 191908
# 192253
# 192598
# 192943
# 193288
# 193633
# 193978
# 194323
# 194668
# 195013
# 195358
# 195703
# 196048
# 196393
# 196738
# 197083
# 197428
# 197773
# 198118
# 198463
# 198808
# 199153
# 199498
# 199843
# 200188
# 200533
# 200878
# 201223
# 201568
# 201913
# 202258
# 202603
# 202948
# 203293
# 203638
# 203983
# 204328
# 204673
# 205018
# 205363
# 205708
# 206053
# 206398
# 206743
# 207088
# 207433
# 207778
# 208123
# 208468
# 208813
# 209158
# 209503
# 209848
# 210193
# 210538
# 210883
# 211228
# 211573
# 211918
# 212263
# 212608
# 212953
# 213298
# 213643
# 213988
# 214333
# 214678
# 215023
# 215368
# 215713
# 216058
# 216403
# 216748
# 217093
# 217438
# 217783
# 218128
# 218473
# 218818
# 219163
# 219508
# 219853
# 220198
# 220543
# 220888
# 221233
# 221578
# 221923
# 222268
# 222613
# 222958
# 223303
# 223648
# 223993
# 224338
# 224683
# 225028
# 225373
# 225718
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967
# 225967

# %%
all_links = list(set(all_links))
len(all_links)
# Out:
# 225967

# %%
with open('all_hindi_wikipedia_links.pkl', 'wb') as f:
    pickle.dump(all_links, f)

# %%
all_links[776]
# Out:
# 'https://hi.wikipedia.org/wiki/%E0%A4%B0%E0%A4%BE%E0%A4%AE%E0%A4%97%E0%A4%82%E0%A4%9C'

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://hi.wikipedia.org/wiki/%E0%A4%B0%E0%A4%BE%E0%A4%AE%E0%A4%97%E0%A4%82%E0%A4%9C"  # Replace with the target URL
response = requests.get(url)

# %%
if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
else:
    print("Error fetching URL:", url)
    soup = None
    
if soup:
    content = soup.text.strip()
    print(content)
    print(len(content) , len(content.split()))
    print(content.split())
# Out:
# रामगंज - विकिपीडिया
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# सामग्री पर जाएँ
#
#
#
#
#
#
#
# मुख्य मेन्यू
#
#
#
#
#
# मुख्य मेन्यू
# साइडबार पर जाएँ
# छुपाएँ
#
#
#
# 		परिभ्रमण
#
#
#
# मुखपृष्ठचौपालहाल में हुए परिवर्तनहाल की घटनाएँसमुदाय प्रवेशद्वारनिर्वाचित विषयवस्तुयादृच्छिक लेख
#
#
#
#
#
# 		योगदान
#
#
#
# प्रयोगपृष्ठअनुरोधदान करें
#
#
#
#
#
# 		सहायता
#
#
#
# सहायतास्वशिक्षाअक्सर पूछे जाने वाले प्रश्नदेवनागरी कैसे टाइप करेंदूतावास (Embassy)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# खोजें
#
#
#
#
#
#
#
#
#
#
#
# खोजें
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# पठन सेटिंग्स
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# खाता बनाएँ
#
# लॉग-इन करें
#
#
#
#
#
#
#
#
# व्यक्तिगत उपकरण
#
#
#
#
#
#  खाता बनाएँ लॉग-इन करें
#
#
#
#
#
# 		लॉग-आउट किए गए संपादकों के लिए पृष्ठ अधिक जानें
#
#
#
# योगदानवार्ता
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# सामग्री
# साइडबार पर जाएँ
# छुपाएँ
#
#
#
#
# शुरुआत
#
#
#
#
#
# 1
# बाहरी कड़ियाँ
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# विषयसूची को टॉगल करें
#
#
#
#
#
#
#
# रामगंज
#
#
#
# भाषाएँ जोड़ें
#
#
#
#
#
# कड़ियाँ जोड़ें
#
#
#
#
#
#
#
#
#
#
#
# लेखसंवाद
#
#
#
#
#
# हिन्दी
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# पढ़ेंसम्पादित करेंइतिहास देखें
#
#
#
#
#
#
#
# उपकरण
#
#
#
#
#
# उपकरण
# साइडबार पर जाएँ
# छुपाएँ
#
#
#
# 		क्रियाएँ
#
#
#
# पढ़ेंसम्पादित करेंइतिहास देखें
#
#
#
#
#
# 		सामान्य
#
#
#
# यहाँ क्या जुड़ता हैपृष्ठ से जुड़े बदलावचित्र अपलोड करेंविशेष पृष्ठस्थायी कड़ीपृष्ठ की जानकारीयह लेख उद्धृत करेंGet shortened URLDownload QR codeछोटा यू॰आर॰एलविकिडेटा आयटम
#
#
#
#
#
# 		मुद्रण/निर्यात
#
#
#
# पुस्तक बनायेंपीडीएफ़ रूप डाउनलोड करेंप्रिन्ट करने लायक
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# पठन सेटिंग्स
# साइडबार पर जाएँ
# छुपाएँ
#
#
#
#
#
#
#
#
#
#
# मुक्त ज्ञानकोश विकिपीडिया से
#
#
#
#
# रामगंज
#
#
# —  गाँव  —
#
#
# निर्देशांक: (निर्देशांक ढूँढें)
#
#
# समय मंडल: आईएसटी (यूटीसी+५:३०)
#
#
# देश
#
#  भारत
#
#
# राज्य
#
# बिहार
#
#
# ज़िला
#
# अररिया
#
#
# आधिकारिक भाषा(एँ)
#
# हिन्दी,उर्दू, मैथिली
#
#
# आधिकारिक जालस्थल: gov.bih.nic.in/
#
#
#
# रामगंज में भारत के बिहार राज्य के अन्तर्गत पुर्णिया मण्डल के अररिया जिले का एक गाँव है।
#
# बिहार के जिले
# बाहरी कड़ियाँ[संपादित करें]
# बिहार - भारत सरकार के आधिकारिक पोर्टल पर
# बिहार सरकार का आधिकारिक जालपृष्ठ (अंग्रेज़ी)
# देवासंबिहारराजधानी: पटनाभूभागदक्षिणी भूभाग * उतरी भूभागबिषयबिहार का इतिहास * (प्राचीन * मध्यकालीन * आधुनिक) * भूगोल * खाना * संस्कृतिपर्यटनगोलघर * अहिल्या स्थान * सीतामढ़ी * सीता कुंड * बोधगया * मुंडेश्वरी मंदिर * राजगीर * देव छठ मेला * देव सूर्य मंदिर * माँ तारा चंडी मंदिर * नालन्दा महाविहार * सोनपुर मेला * बराबर गुफाएँ * मंदर पर्वत * गया * देव, बिहारप्रमंडलसारण * कोसी * तिरहुत * दरभंगा * पटना * पूर्णिया * भागलपुर * मगध * मुंगेरजिलेसारण * अरवल * अररिया * औरंगाबाद * कटिहार * किशनगंज * कैमुर * खगड़िया * गया * गोपालगंज * बेगूसराय * दरभंगा * मधुबनी * समस्तीपुर * बाँका * भागलपुर * मधेपुरा * सहरसा * सुपौल * जहानाबाद * नवादा * जमुई * मुंगेर * लखीसराय * शेखपुरा * भोजपुर * बक्सर * पटना * रोहतास * नालंदा  * सीवान * पश्चिम चंपारण * पूर्वी चंपारण * पूर्णिया *मुजफ्फरपुर * शिवहर * सीतामढ़ी · वैशालीअंतर्राष्ट्रीय हवाई अड्डागया अंतर्राष्ट्रीय हवाई-अड्डा * जय प्रकाश नारायण विमानक्षेत्र पटना * बिहटा वायुसेना हवाई-अड्डानगर निगमपटना नगर निगम *  छपरा नगर निगम * बिहारशरीफ नगर निगम * दरभंगा नगर निगम * आरा नगर निगम * भागलपुर नगर निगम * गया नगर निगम * मुजफ्फरपुर नगर निगम * मुंगेर नगर निगम * बेगूसराय नगर निगम * पूर्णिया नगर निगम * कटिहार नगर निगमनगर परिषदनगर परिषद् दानापुर निजामत * बख्तियारपुर नगर परिषद * फतुहा नगर परिषद * कांटी नगर परिषद *मोतीपुर नगर परिषद * बरबीघा नगर परिषद * महानार नगर परिषदनगर पंचायतसोनपुर नगर पंचायत
#
#
#
#
# "https://hi.wikipedia.org/w/index.php?title=रामगंज&oldid=4791011" से प्राप्त
# श्रेणियाँ: बिहार के गाँवअरारियागाँव
#
#
#
#
#
#
#  अन्तिम परिवर्तन 13:33, 15 जून 2020।
# यह सामग्री क्रियेटिव कॉमन्स ऍट्रीब्यूशन/शेयर-अलाइक लाइसेंस के तहत उपलब्ध है;
# अन्य शर्ते लागू हो सकती हैं।
# विस्तार से जानकारी हेतु देखें उपयोग की शर्तें
#
#
# गोपनीयता नीति
# विकिपीडिया के बारे में
# अस्वीकरण
# Code of Conduct
# विकासक
# सांख्यिकी
# कुकी का वर्णन
# मोबाइल दृश्य
# 3529 497
# ['रामगंज', '-', 'विकिपीडिया', 'सामग्री', 'पर', 'जाएँ', 'मुख्य', 'मेन्यू', 'मुख्य', 'मेन्यू', 'साइडबार', 'पर', 'जाएँ', 'छुपाएँ', 'परिभ्रमण', 'मुखपृष्ठचौपालहाल', 'में', 'हुए', 'परिवर्तनहाल', 'की', 'घटनाएँसमुदाय', 'प्रवेशद्वारनिर्वाचित', 'विषयवस्तुयादृच्छिक', 'लेख', 'योगदान', 'प्रयोगपृष्ठअनुरोधदान', 'करें', 'सहायता', 'सहायतास्वशिक्षाअक्सर', 'पूछे', 'जाने', 'वाले', 'प्रश्नदेवनागरी', 'कैसे', 'टाइप', 'करेंदूतावास', '(Embassy)', 'खोजें', 'खोजें', 'पठन', 'सेटिंग्स', 'खाता', 'बनाएँ', 'लॉग-इन', 'करें', 'व्यक्तिगत', 'उपकरण', 'खाता', 'बनाएँ', 'लॉग-इन', 'करें', 'लॉग-आउट', 'किए', 'गए', 'संपादकों', 'के', 'लिए', 'पृष्ठ', 'अधिक', 'जानें', 'योगदानवार्ता', 'सामग्री', 'साइडबार', 'पर', 'जाएँ', 'छुपाएँ', 'शुरुआत', '1', 'बाहरी', 'कड़ियाँ', 'विषयसूची', 'को', 'टॉगल', 'करें', 'रामगंज', 'भाषाएँ', 'जोड़ें', 'कड़ियाँ', 'जोड़ें', 'लेखसंवाद', 'हिन्दी', 'पढ़ेंसम्पादित', 'करेंइतिहास', 'देखें', 'उपकरण', 'उपकरण', 'साइडबार', 'पर', 'जाएँ', 'छुपाएँ', 'क्रियाएँ', 'पढ़ेंसम्पादित', 'करेंइतिहास', 'देखें', 'सामान्य', 'यहाँ', 'क्या', 'जुड़ता', 'हैपृष्ठ', 'से', 'जुड़े', 'बदलावचित्र', 'अपलोड', 'करेंविशेष', 'पृष्ठस्थायी', 'कड़ीपृष्ठ', 'की', 'जानकारीयह', 'लेख', 'उद्धृत', 'करेंGet', 'shortened', 'URLDownload', 'QR', 'codeछोटा', 'यू॰आर॰एलविकिडेटा', 'आयटम', 'मुद्रण/निर्यात', 'पुस्तक', 'बनायेंपीडीएफ़', 'रूप', 'डाउनलोड', 'करेंप्रिन्ट', 'करने', 'लायक', 'पठन', 'सेटिंग्स', 'साइडबार', 'पर', 'जाएँ', 'छुपाएँ', 'मुक्त', 'ज्ञानकोश', 'विकिपीडिया', 'से', 'रामगंज', '—', 'गाँव', '—', 'निर्देशांक:', '(निर्देशांक', 'ढूँढें)', 'समय', 'मंडल:', 'आईएसटी', '(यूटीसी+५:३०)', 'देश', 'भारत', 'राज्य', 'बिहार', 'ज़िला', 'अररिया', 'आधिकारिक', 'भाषा(एँ)', 'हिन्दी,उर्दू,', 'मैथिली', 'आधिकारिक', 'जालस्थल:', 'gov.bih.nic.in/', 'रामगंज', 'में', 'भारत', 'के', 'बिहार', 'राज्य', 'के', 'अन्तर्गत', 'पुर्णिया', 'मण्डल', 'के', 'अररिया', 'जिले', 'का', 'एक', 'गाँव', 'है।', 'बिहार', 'के', 'जिले', 'बाहरी', 'कड़ियाँ[संपादित', 'करें]', 'बिहार', '-', 'भारत', 'सरकार', 'के', 'आधिकारिक', 'पोर्टल', 'पर', 'बिहार', 'सरकार', 'का', 'आधिकारिक', 'जालपृष्ठ', '(अंग्रेज़ी)', 'देवासंबिहारराजधानी:', 'पटनाभूभागदक्षिणी', 'भूभाग', '*', 'उतरी', 'भूभागबिषयबिहार', 'का', 'इतिहास', '*', '(प्राचीन', '*', 'मध्यकालीन', '*', 'आधुनिक)', '*', 'भूगोल', '*', 'खाना', '*', 'संस्कृतिपर्यटनगोलघर', '*', 'अहिल्या', 'स्थान', '*', 'सीतामढ़ी', '*', 'सीता', 'कुंड', '*', 'बोधगया', '*', 'मुंडेश्वरी', 'मंदिर', '*', 'राजगीर', '*', 'देव', 'छठ', 'मेला', '*', 'देव', 'सूर्य', 'मंदिर', '*', 'माँ', 'तारा', 'चंडी', 'मंदिर', '*', 'नालन्दा', 'महाविहार', '*', 'सोनपुर', 'मेला', '*', 'बराबर', 'गुफाएँ', '*', 'मंदर', 'पर्वत', '*', 'गया', '*', 'देव,', 'बिहारप्रमंडलसारण', '*', 'कोसी', '*', 'तिरहुत', '*', 'दरभंगा', '*', 'पटना', '*', 'पूर्णिया', '*', 'भागलपुर', '*', 'मगध', '*', 'मुंगेरजिलेसारण', '*', 'अरवल', '*', 'अररिया', '*', 'औरंगाबाद', '*', 'कटिहार', '*', 'किशनगंज', '*', 'कैमुर', '*', 'खगड़िया', '*', 'गया', '*', 'गोपालगंज', '*', 'बेगूसराय', '*', 'दरभंगा', '*', 'मधुबनी', '*', 'समस्तीपुर', '*', 'बाँका', '*', 'भागलपुर', '*', 'मधेपुरा', '*', 'सहरसा', '*', 'सुपौल', '*', 'जहानाबाद', '*', 'नवादा', '*', 'जमुई', '*', 'मुंगेर', '*', 'लखीसराय', '*', 'शेखपुरा', '*', 'भोजपुर', '*', 'बक्सर', '*', 'पटना', '*', 'रोहतास', '*', 'नालंदा', '*', 'सीवान', '*', 'पश्चिम', 'चंपारण', '*', 'पूर्वी', 'चंपारण', '*', 'पूर्णिया', '*मुजफ्फरपुर', '*', 'शिवहर', '*', 'सीतामढ़ी', '·', 'वैशालीअंतर्राष्ट्रीय', 'हवाई', 'अड्डागया', 'अंतर्राष्ट्रीय', 'हवाई-अड्डा', '*', 'जय', 'प्रकाश', 'नारायण', 'विमानक्षेत्र', 'पटना', '*', 'बिहटा', 'वायुसेना', 'हवाई-अड्डानगर', 'निगमपटना', 'नगर', 'निगम', '*', 'छपरा', 'नगर', 'निगम', '*', 'बिहारशरीफ', 'नगर', 'निगम', '*', 'दरभंगा', 'नगर', 'निगम', '*', 'आरा', 'नगर', 'निगम', '*', 'भागलपुर', 'नगर', 'निगम', '*', 'गया', 'नगर', 'निगम', '*', 'मुजफ्फरपुर', 'नगर', 'निगम', '*', 'मुंगेर', 'नगर', 'निगम', '*', 'बेगूसराय', 'नगर', 'निगम', '*', 'पूर्णिया', 'नगर', 'निगम', '*', 'कटिहार', 'नगर', 'निगमनगर', 'परिषदनगर', 'परिषद्', 'दानापुर', 'निजामत', '*', 'बख्तियारपुर', 'नगर', 'परिषद', '*', 'फतुहा', 'नगर', 'परिषद', '*', 'कांटी', 'नगर', 'परिषद', '*मोतीपुर', 'नगर', 'परिषद', '*', 'बरबीघा', 'नगर', 'परिषद', '*', 'महाना ...
